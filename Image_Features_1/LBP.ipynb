# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern

# 이미지 로드 및 전처리
image = cv2.imread('stone.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# LBP 특징 추출
radius = 3
n_points = 8 * radius
lbp = local_binary_pattern(gray, n_points, radius, method='uniform')

# LBP 히스토그램 계산
(hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))

# 히스토그램 정규화
hist = hist.astype("float")
hist /= (hist.sum() + 1e-6)

# 결과 시각화
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(gray, cmap='gray')
plt.title('Original Image')
plt.subplot(122)
plt.imshow(lbp, cmap='gray')
plt.title('LBP Image')
plt.show()

# 히스토그램 시각화
plt.figure()
plt.plot(hist, color='black')
plt.title('LBP Histogram')
plt.xlabel('LBP value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# wood.png 비교

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern

# 이미지 로드 및 전처리
image = cv2.imread('wood.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# LBP 특징 추출
radius = 3
n_points = 8 * radius
lbp = local_binary_pattern(gray, n_points, radius, method='uniform')

# LBP 히스토그램 계산
(hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))

# 히스토그램 정규화
hist = hist.astype("float")
hist /= (hist.sum() + 1e-6)

# 결과 시각화
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(gray, cmap='gray')
plt.title('Original Image')
plt.subplot(122)
plt.imshow(lbp, cmap='gray')
plt.title('LBP Image')
plt.show()

# 히스토그램 시각화
plt.figure()
plt.plot(hist, color='black')
plt.title('LBP Histogram')
plt.xlabel('LBP value')
plt.ylabel('Frequency')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern

def extract_lbp_features(image_path, radius=3, n_points=8*2):
    # 이미지 로드 및 전처리
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # LBP 특징 추출
    lbp = local_binary_pattern(gray, n_points, radius, method='uniform')

    # LBP 히스토그램 계산
    bins=np.arange(10, n_points + 3)
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(13, n_points + 3), range=(0, n_points + 2))
    print(bins)
    # 히스토그램 정규화
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    
    return hist

# 예제 이미지 경로
image_path1 = 'stone.png'
image_path2 = 'stone2.png'
image_path3 = 'wood.png'
image_path4 = 'water.png'

# 네 개의 특징 벡터 추출
feature_vector1 = extract_lbp_features(image_path1)
feature_vector2 = extract_lbp_features(image_path2)
feature_vector3 = extract_lbp_features(image_path3)
feature_vector4 = extract_lbp_features(image_path4)

# 특징 벡터 출력
print("Feature vector 1:")
print(feature_vector1)
print("Feature vector 2:")
print(feature_vector2)
print("Feature vector 3:")
print(feature_vector3)
print("Feature vector 4:")
print(feature_vector4)

# 네 개의 특징 벡터 플롯
plt.figure()
plt.plot(feature_vector1, color='red', label='Feature Vector 1')
plt.plot(feature_vector2, color='green', label='Feature Vector 2')
plt.plot(feature_vector3, color='blue', label='Feature Vector 3')
plt.plot(feature_vector4, color='purple', label='Feature Vector 4')
plt.title('LBP Histogram Features')
plt.xlabel('LBP value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# [10 11 12 13 14 15 16 17 18]
# [10 11 12 13 14 15 16 17 18]
# [10 11 12 13 14 15 16 17 18]
# [10 11 12 13 14 15 16 17 18]
# Feature vector 1:
# [0.02076537 0.03470568 0.07657166 0.08748974 0.78046755]
# Feature vector 2:
# [0.02107909 0.03264688 0.07657593 0.08780098 0.78189712]
# Feature vector 3:
# [0.01554469 0.01023716 0.08794383 0.07208002 0.8141943 ]
# Feature vector 4:
# [0.05708461 0.0608972  0.07463058 0.1223964  0.68499121]
